# %%
import pandas as pd
import numpy as np

# %%
cd "c:\\work stuff\\Projects\\Credit Scoring Project\\Insurance-Credit-Scoring\\Data\\raw_data"
# Out:
# c:\work stuff\Projects\Credit Scoring Project\Insurance-Credit-Scoring\Data\raw_data

# %% [markdown]
# # LIFE INSURANCE

# %%
### only works for 2019 to 2017 since they were already in excel format
files= ["2020-Annual-Insurance-Industry-Statistics(1).xls","2019 Annual Insurance Industry Statistics.xlsm","2018 Annual Statistics 28062019.xls","2017-Annual-Insurance-Statistics-Uploaded.xlsm"]
new_df= pd.DataFrame()
c=0
for fil in files:
    c+=1
    f1 = pd.ExcelFile(fil)
    ## reading the specific sheets
    sheet1= pd.read_excel(f1,"APPENDIX 4 I",header=3)
    sheet2 = pd.read_excel(f1,"APPENDIX 4 II",header=3)
    sheet3 = pd.read_excel(f1,"APPENDIX 4 III",header=4)
    ### dropping the unnamed column
    sheet1.drop("Unnamed: 0",axis=1,inplace=True)
    sheet2.drop("Unnamed: 0",axis=1,inplace=True)
    sheet3.drop("Unnamed: 0",axis=1,inplace=True)
    ### setting the df index
    sheet1.set_index("Company",inplace=True)
    sheet2.set_index("Company",inplace=True)
    sheet3.set_index("Company",inplace=True)

    ### concatinating the data sheets
    new_df = pd.concat([new_df,sheet1.T,sheet2.T,sheet3.T])

# %%
new_df.head()
# Out:
# Company                       Share Capital Share Premium_x000D_\n  \
# ABSA LIFE ASSURANCE KENYA          699000.0                    0.0
# APA LIFE ASSURANCE COMPANY         700000.0                    0.0
# BRITAM LIFE ASSURANCE              400000.0                    0.0
# CAPEX LIFE ASSURANCE COMPANY       345000.0                    0.0
# CIC LIFE ASSURANCE COMPANY         800000.0                    0.0
#
# Company                       Revaluation Reserves Statutory Reserves  \
# ABSA LIFE ASSURANCE KENYA                      0.0           314168.0
# APA LIFE ASSURANCE COMPANY                    95.0            73636.0
# BRITAM LIFE ASSURANCE                          0.0                0.0
# CAPEX LIFE ASSURANCE COMPANY                1613.0           -31211.0
# CIC LIFE ASSURANCE COMPANY                     0.0          1183825.0
#
# Company                       Retained Earnings Other Reserves  \
# ABSA LIFE ASSURANCE KENYA                   0.0            0.0
# APA LIFE ASSURANCE COMPANY            -101459.0            0.0
# BRITAM LIFE ASSURANCE                  300000.0      5454465.0
# CAPEX LIFE ASSURANCE COMPANY                0.0          823.0
# CIC LIFE ASSURANCE COMPANY              71861.0        49613.0
#
# Company                       Total Equity_x000D_\n Underwriting Provisions  \
# ABSA LIFE ASSURANCE KENYA                 1013168.0                     0.0
# APA LIFE ASSURANCE COMPANY                 672272.0                280263.0
# BRITAM LIFE ASSURANCE                     6154465.0                700805.0
# CAPEX LIFE ASSURANCE COMPANY               316225.0                  5373.0
# CIC LIFE ASSURANCE COMPANY                2105299.0                757370.0
#
# Company                       Actuarial Contract Liabilities  \
# ABSA LIFE ASSURANCE KENYA                          3279111.0
# APA LIFE ASSURANCE COMPANY                         5600351.0
# BRITAM LIFE ASSURANCE                             85142730.0
# CAPEX LIFE ASSURANCE COMPANY                        568413.0
# CIC LIFE ASSURANCE COMPANY                        12545850.0
#
# Company                       LongTerm Liabilities  ... Term Deposits  \
# ABSA LIFE ASSURANCE KENYA                 400000.0  ...      184833.0
# APA LIFE ASSURANCE COMPANY                 23859.0  ...      832863.0
# BRITAM LIFE ASSURANCE                    2337627.0  ...      782375.0
# CAPEX LIFE ASSURANCE COMPANY                   0.0  ...        2000.0
# CIC LIFE ASSURANCE COMPANY                508616.0  ...     2017745.0
#
# Company                       Cash and Cash Balances Outstanding Premiums  \
# ABSA LIFE ASSURANCE KENYA                   150154.0             850253.0
# APA LIFE ASSURANCE COMPANY                   99619.0             287211.0
# BRITAM LIFE ASSURANCE                       366635.0             753729.0
# CAPEX LIFE ASSURANCE COMPANY                 42578.0              84635.0
# CIC LIFE ASSURANCE COMPANY                  152138.0             836162.0
#
# Company                       Other Receivables Other Assets  \
# ABSA LIFE ASSURANCE KENYA               11586.0      78001.0
# APA LIFE ASSURANCE COMPANY              25309.0      61579.0
# BRITAM LIFE ASSURANCE                  698744.0   10878417.0
# CAPEX LIFE ASSURANCE COMPANY                0.0      34919.0
# CIC LIFE ASSURANCE COMPANY             442099.0     685971.0
#
# Company                       Intangible Assets Total Assets  \
# ABSA LIFE ASSURANCE KENYA                   0.0    5590564.0
# APA LIFE ASSURANCE COMPANY              26880.0    6775070.0
# BRITAM LIFE ASSURANCE                  937442.0   96062202.0
# CAPEX LIFE ASSURANCE COMPANY             3841.0     944457.0
# CIC LIFE ASSURANCE COMPANY               1346.0   16568270.0
#
# Company                       Amounts in thousand Shillings                                                                                                                                                                                           \
# ABSA LIFE ASSURANCE KENYA                                                    NaN
# APA LIFE ASSURANCE COMPANY                                                   NaN
# BRITAM LIFE ASSURANCE                                                        NaN
# CAPEX LIFE ASSURANCE COMPANY                                                 NaN
# CIC LIFE ASSURANCE COMPANY                                                   NaN
#
# Company                       Amounts in thousand Shillings                                                                                                                                                                                                 \
# ABSA LIFE ASSURANCE KENYA                                                    NaN
# APA LIFE ASSURANCE COMPANY                                                   NaN
# BRITAM LIFE ASSURANCE                                                        NaN
# CAPEX LIFE ASSURANCE COMPANY                                                 NaN
# CIC LIFE ASSURANCE COMPANY                                                   NaN
#
# Company                       Amounts in Thousand Shillings
# ABSA LIFE ASSURANCE KENYA                               NaN
# APA LIFE ASSURANCE COMPANY                              NaN
# BRITAM LIFE ASSURANCE                                   NaN
# CAPEX LIFE ASSURANCE COMPANY                            NaN
# CIC LIFE ASSURANCE COMPANY                              NaN
#
# [5 rows x 37 columns]

# %%
len(new_df.columns)
# Out:
# 37

# %%
new_df.to_csv("Life_BS_20_17.csv")

# %% [markdown]
# ### pdfs converted to excel

# %%
page_list15 = []
for i in range(59,62):
    page_list15.append("Table "+str(i))

# %%
page_list16 = []
for i in range(63,66):
    page_list16.append("Table "+str(i))

# %%
page_list14 = []
for i in range(32,35):
    page_list14.append("Table "+str(i))

# %%
page_list13 = []
for i in range(36,39):
    page_list13.append("Table "+str(i))

# %%
files2= ["Annual-_Industry_Report_2016.xlsx","Annual Report 2015.xlsx","Annual-Report-2014-12.10.2015-Final.xlsx","Latest 2013 IRA Annual Report.xlsx"]
pages=[page_list16,page_list15,page_list14,page_list13]
c=1
new_df2= pd.DataFrame()
for filz,page in zip(files2,pages):
    f2 = pd.ExcelFile(filz)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f2,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("COMPANY",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            new_df2 = pd.concat([new_df2,sheet_t])
        except KeyError:
            sheet=  pd.read_excel(f2,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("COMPANY",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            new_df2 = pd.concat([new_df2,sheet_t])
            
            print(sheet_t.columns)
            #c+=1
# Out:
# Index(['Share Capital', 'Share Premium', 'Revaluation Reserves',
#        'Statutory Reserves', 'Retained Earnings', 'Other Reserves',
#        'Total Equity', 'Underwriting Provisions',
#        'Actuarial Contract Liabilities', 'LongTerm Liabilities',
#        'Current Liabilities', 'Total Equity And Liabilities',
#        'Land And Buildings', 'Investment Property', 'Other Fixed Assets',
#        'Government Securities', 'Other Securities',
#        'Investment in Related Companies', 'Corporate Bonds',
#        'Commercial Papers', 'Debentures', 'Ordinary Shares Quoted',
#        'Ordinary Shares Unquoted', 'Preference Shares Quoted',
#        'Preference Shares Unquoted', 'Loans Secured & Unsecured', 'Mortgages',
#        'Term Deposits', 'Cash and Cash Balances', 'Outstanding Premiums',
#        'Other Receivables', 'Other Assets', 'Intangible Assets',
#        'Total Assets',
#        'Amounts in thousand Shillings                                                                                                                                                                                                                                                                                                    Continued next page'],
#       dtype='object', name='COMPANY')
# Index(['Share Capital', 'Share Premium', 'Revaluation Reserves',
#        'Statutory Reserves', 'Retained Earnings', 'Other Reserves',
#        'Total Equity', 'Underwriting Provisions',
#        'Actuarial Contract Liabilities', 'LongTerm Liabilities',
#        'Current Liabilities', 'Total Equity And Liabilities',
#        'Land And Buildings', 'Investment Property', 'Other Fixed Assets',
#        'Government Securities', 'Other Securities',
#        'Investment in Related Companies', 'Corporate Bonds',
#        'Commercial Papers', 'Debentures', 'Ordinary Shares Quoted',
#        'Ordinary Shares Unquoted', 'Preference Shares Quoted',
#        'Preference Shares Unquoted', 'Loans Secured & Unsecured', 'Mortgages',
#        'Term Deposits', 'Cash and Cash Balances', 'Outstanding Premiums',
#        'Other Receivables', 'Other Assets', 'Intangible Assets',
#        'Total Assets', 'Amounts in Thousand Shillings'],
#       dtype='object', name='COMPANY')
# Index(['Share Capital', 'Share Premium', 'Revaluation Reserves',
#        'Statutory Reserves', 'Retained Earnings', 'Other Reserves',
#        'Total Equity', 'Underwriting Provisions',
#        'Actuarial Contract Liabilities', 'LongTerm Liabilities',
#        'Current Liabilities', 'Total Equity And Liabilities',
#        'Land And Buildings', 'Investment Property', 'Other Fixed Assets',
#        'Government Securities', 'Other Securities',
#        'Investment in Related Companies', 'Corporate Bonds',
#        'Commercial Papers', 'Debentures', 'Ordinary Shares Quoted',
#        'Ordinary Shares Unquoted', 'Preference Shares Quoted',
#        'Preference Shares Unquoted', 'Loans Secured & Unsecured', 'Mortgages',
#        'Term Deposits', 'Cash and Cash Balances', 'Outstanding Premiums',
#        'Other Receivables', 'Other Assets', 'Intangible Assets',
#        'Total Assets',
#        'Amounts in thousand Shillings                                                                                                                                                                                                                                                                                                    Continued next page'],
#       dtype='object', name='COMPANY')
# Index(['Share Capital', 'Share Premium', 'Revaluation Reserves',
#        'Statutory Reserves', 'Retained Earnings', 'Other Reserves',
#        'Total Equity', 'Underwriting Provisions',
#        'Actuarial Contract Liabilities', 'LongTerm Liabilities',
#        'Current Liabilities', 'Total Equity And Liabilities',
#        'Land And Buildings', 'Investment Property', 'Other Fixed Assets',
#        'Government Securities', 'Other Securities',
#        'Investment in Related Companies', 'Corporate Bonds',
#        'Commercial Papers', 'Debentures', 'Ordinary Shares Quoted',
#        'Ordinary Shares Unquoted', 'Preference Shares Quoted',
#        'Preference Shares Unquoted', 'Loans Secured & Unsecured', 'Mortgages',
#        'Term Deposits', 'Cash and Cash Balances', 'Outstanding Premiums',
#        'Other Receivables', 'Other Assets', 'Intangible Assets',
#        'Total Assets', 'Amounts in Thousand Shillings'],
#       dtype='object', name='COMPANY')
# Index(['Share Capital', 'Share Premium', 'Revaluation Reserves',
#        'Statutory Reserves', 'Retained Earnings', 'Other Reserves',
#        'Total Equity', 'Underwriting Provisions',
#        'Actuarial Contract Liabilities', 'LongTerm Liabilities',
#        'Current Liabilities', 'Total Equity And Liabilities',
#        'Land And Buildings', 'Investment Property', 'Other Fixed Assets',
#        'Government Securities', 'Other Securities',
#        'Investment in Related Companies', 'Corporate Bonds',
#        'Commercial Papers', 'Debentures', 'Ordinary Shares Quoted',
#        'Ordinary Shares Unquoted', 'Preference Shares Quoted',
#        'Preference Shares Unquoted', 'Loans Secured & Unsecured', 'Mortgages',
#        'Term Deposits', 'Cash and Cash Balances', 'Outstanding Premiums',
#        'Other Receivables', 'Other Assets', 'Intangible Assets',
#        'Total Assets', 'Amounts in thousand Shillings'],
#       dtype='object', name='COMPANY')
# Index(['Share Capital', 'Share Premium', 'Revaluation Reserves',
#        'Statutory Reserves', 'Retained Earnings', 'Other Reserves',
#        'Total Equity', 'Underwriting Provisions',
#        'Actuarial Contract Liabilities', 'LongTerm Liabilities',
#        'Current Liabilities', 'Total Equity And Liabilities',
#        'Land And Buildings', 'Investment Property', 'Other Fixed Assets',
#        'Government Securities', 'Other Securities',
#        'Investment in Related Companies', 'Corporate Bonds',
#        'Commercial Papers', 'Debentures', 'Ordinary Shares Quoted',
#        'Ordinary Shares Unquoted', 'Preference Shares Quoted',
#        'Preference Shares Unquoted', 'Loans Secured & Unsecured', 'Mortgages',
#        'Term Deposits', 'Cash and Cash Balances', 'Outstanding Premiums',
#        'Other Receivables', 'Other Assets', 'Intangible Assets',
#        'Total Assets', 'Amounts in Thousand Shillings'],
#       dtype='object', name='COMPANY')

# %%
new_df2.head()
# Out:
# COMPANY                       Share Capital Share Premium  \
# APA LIFE\nASSURANCE COMPANY         450,000             -
# BARCLAYS LIFE ASSURANCE             450,000             -
# BRITAM LIFE ASSURANCE               880,000             -
# CANNON\nASSURANCE COMPANY           150,000             -
# CAPEX LIFE\nASSURANCE COMPANY       150,000             -
#
# COMPANY                       Revaluation Reserves Statutory Reserves  \
# APA LIFE\nASSURANCE COMPANY                  4,106              7,840
# BARCLAYS LIFE ASSURANCE                      1,915        ( 476,999 )
# BRITAM LIFE ASSURANCE                            -                  -
# CANNON\nASSURANCE COMPANY                        -            204,897
# CAPEX LIFE\nASSURANCE COMPANY                  778             45,023
#
# COMPANY                       Retained Earnings Other Reserves Total Equity  \
# APA LIFE\nASSURANCE COMPANY          ( 89,451 )              -      372,495
# BARCLAYS LIFE ASSURANCE                  78,323              -       53,239
# BRITAM LIFE ASSURANCE                         -      7,837,962    8,717,962
# CANNON\nASSURANCE COMPANY                     -        461,946      816,843
# CAPEX LIFE\nASSURANCE COMPANY                 -         48,793      244,593
#
# COMPANY                       Underwriting Provisions  \
# APA LIFE\nASSURANCE COMPANY                   150,623
# BARCLAYS LIFE ASSURANCE                             -
# BRITAM LIFE ASSURANCE                         753,071
# CANNON\nASSURANCE COMPANY                      54,289
# CAPEX LIFE\nASSURANCE COMPANY                   2,099
#
# COMPANY                       Actuarial Contract Liabilities  \
# APA LIFE\nASSURANCE COMPANY                        3,313,362
# BARCLAYS LIFE ASSURANCE                              818,405
# BRITAM LIFE ASSURANCE                             39,046,506
# CANNON\nASSURANCE COMPANY                            617,169
# CAPEX LIFE\nASSURANCE COMPANY                         74,383
#
# COMPANY                       LongTerm Liabilities  ... Other Receivables  \
# APA LIFE\nASSURANCE COMPANY                  3,385  ...            33,015
# BARCLAYS LIFE ASSURANCE                    400,000  ...             4,359
# BRITAM LIFE ASSURANCE                    3,359,126  ...         1,168,232
# CANNON\nASSURANCE COMPANY                  131,120  ...                 -
# CAPEX LIFE\nASSURANCE COMPANY              111,741  ...                 -
#
# COMPANY                       Other Assets Intangible Assets Total Assets  \
# APA LIFE\nASSURANCE COMPANY         13,179            15,551    3,979,418
# BARCLAYS LIFE ASSURANCE                757                 -    1,625,393
# BRITAM LIFE ASSURANCE           14,901,597         1,007,766   52,863,086
# CANNON\nASSURANCE COMPANY           37,770             1,069    1,703,985
# CAPEX LIFE\nASSURANCE COMPANY        1,129                 -      471,636
#
# COMPANY                       Amounts in thousand Shillings                                                                                                                                                                                                                                  Continued next page  \
# APA LIFE\nASSURANCE COMPANY                                                  NaN
# BARCLAYS LIFE ASSURANCE                                                      NaN
# BRITAM LIFE ASSURANCE                                                        NaN
# CANNON\nASSURANCE COMPANY                                                    NaN
# CAPEX LIFE\nASSURANCE COMPANY                                                NaN
#
# COMPANY                       Amounts in thousand Shillings                                                                                                                                                                                                                                                                                                    Continued next page  \
# APA LIFE\nASSURANCE COMPANY                                                  NaN
# BARCLAYS LIFE ASSURANCE                                                      NaN
# BRITAM LIFE ASSURANCE                                                        NaN
# CANNON\nASSURANCE COMPANY                                                    NaN
# CAPEX LIFE\nASSURANCE COMPANY                                                NaN
#
# COMPANY                       Amounts in Thousand Shillings  \
# APA LIFE\nASSURANCE COMPANY                             NaN
# BARCLAYS LIFE ASSURANCE                                 NaN
# BRITAM LIFE ASSURANCE                                   NaN
# CANNON\nASSURANCE COMPANY                               NaN
# CAPEX LIFE\nASSURANCE COMPANY                           NaN
#
# COMPANY                       Amounts in thousand Shillings                                                                                                                                                                                                                                                  Continued next page  \
# APA LIFE\nASSURANCE COMPANY                                                  NaN
# BARCLAYS LIFE ASSURANCE                                                      NaN
# BRITAM LIFE ASSURANCE                                                        NaN
# CANNON\nASSURANCE COMPANY                                                    NaN
# CAPEX LIFE\nASSURANCE COMPANY                                                NaN
#
# COMPANY                       Amounts in thousand Shillings                                                                                                                                                                                                                                               Continued next page  \
# APA LIFE\nASSURANCE COMPANY                                                  NaN
# BARCLAYS LIFE ASSURANCE                                                      NaN
# BRITAM LIFE ASSURANCE                                                        NaN
# CANNON\nASSURANCE COMPANY                                                    NaN
# CAPEX LIFE\nASSURANCE COMPANY                                                NaN
#
# COMPANY                       Amounts in thousand Shillings
# APA LIFE\nASSURANCE COMPANY                             NaN
# BARCLAYS LIFE ASSURANCE                                 NaN
# BRITAM LIFE ASSURANCE                                   NaN
# CANNON\nASSURANCE COMPANY                               NaN
# CAPEX LIFE\nASSURANCE COMPANY                           NaN
#
# [5 rows x 40 columns]

# %%
new_df2.to_csv("Life_16_13.csv")

# %%
import re

# %% [markdown]
# ### batch 3 2006-2009

# %%
page_list06 = []
for i in range(32,35):
    page_list06.append("Table "+str(i))

# %%
page_list07 = []
for i in range(40,43):
    page_list07.append("Table "+str(i))

# %%
page_list09 = []
for i in range(40,43):
    page_list09.append("Table "+str(i))

# %%
page_list10 = []
for i in range(34,36):
    page_list10.append("Table "+str(i))

# %%
page_list11 = []
for i in range(28,31):
    page_list11.append("Table "+str(i))

# %%
page_list12 = []
for i in range(59,62):
    page_list12.append("Table "+str(i))

# %%
files3= ["Annual_Report_Year_2006.xlsx","2007 Annual Report.xlsx","2009 Annual Report.xlsx"]
pages3=[page_list06,page_list07,page_list09]
c=1
new_df3= pd.DataFrame()
for fil3,page in zip(files3,pages3):
    f3 = pd.ExcelFile(fil3)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f3,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            #sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            new_df3 = pd.concat([new_df3,sheet_t])
        except KeyError:
            sheet=  pd.read_excel(f3,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            #sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            new_df3 = pd.concat([new_df3,sheet_t])
            
        print(len(sheet_t.columns))
# Out:
# 33
# 33
# 33
# 33
# 33
# 33
# 34
# 34
# 34

# %%
new_df3.to_csv("Life_BS_09_06.csv")

# %% [markdown]
# ### batch 4 bunched 2getha since they have more similar columns

# %%
files4= ["IRA Annual Report 2012(1).xlsx","IRA ANNUAL REPORT 2011 FINAL.xlsx","2010 insurance industry report.xlsx"]
pages4=[page_list12,page_list11,page_list10]
c=1
new_df4= pd.DataFrame()
for fil4,page in zip(files4,pages4):
    f4 = pd.ExcelFile(fil4)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f4,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            #
            sheet_t.columns = sheet_t.columns.str.strip()
            #sheet_t.columns.rename({'Unapprtd Surplus/Retained earnings (Net)':'Unapprtd Surplus/Retained earnings'})
            #sheet_t.columns = sheet_t.columns.str.replace('Unapprtd Surplus/Retained earnings (Net)','Unapprtd Surplus/Retained earnings')
            sheet_t.columns = sheet_t.columns.str.replace('   ',' ')
            sheet_t.columns = sheet_t.columns.str.replace('  ',' ')
            
            sheet_t.columns = sheet_t.columns.str.replace('-',' ')
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            new_df4 = pd.concat([new_df4,sheet_t])
        except KeyError:
            sheet=  pd.read_excel(f4,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            #
            sheet_t.columns = sheet_t.columns.str.strip()
            #sheet_t.columns.rename({'Unapprtd Surplus/Retained earnings (Net)':'Unapprtd Surplus/Retained earnings'})
            sheet_t.columns = sheet_t.columns.str.replace('   ',' ')
            sheet_t.columns = sheet_t.columns.str.replace('  ',' ')
            sheet_t.columns = sheet_t.columns.str.replace('-',' ')
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            new_df4 = pd.concat([new_df4,sheet_t])    
        print(sheet_t.columns)
# Out:
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID_UP_CAPITAL',
#                                    'STATUTORY_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#             'UNAPPRTD_SURPLUS/RETAINED_EARNINGS_(NET)',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                             'UNQUOTED_ORDINARY_SHARES',
#                               'QUOTED_ORDINARY_SHARES',
#          'SECURED_LOANS_(INCL.LOANS_ON_LIFE_POLICIES)',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE_INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan],
#       dtype='object', name='ITEM')
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID_UP_CAPITAL',
#                                    'STATUTORY_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#             'UNAPPRTD_SURPLUS/RETAINED_EARNINGS_(NET)',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                             'UNQUOTED_ORDINARY_SHARES',
#                               'QUOTED_ORDINARY_SHARES',
#          'SECURED_LOANS_(INCL.LOANS_ON_LIFE_POLICIES)',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE_INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan],
#       dtype='object', name='ITEM')
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID_UP_CAPITAL',
#                                    'STATUTORY_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#             'UNAPPRTD_SURPLUS/RETAINED_EARNINGS_(NET)',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                             'UNQUOTED_ORDINARY_SHARES',
#                               'QUOTED_ORDINARY_SHARES',
#          'SECURED_LOANS_(INCL.LOANS_ON_LIFE_POLICIES)',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE_INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan],
#       dtype='object', name='ITEM')
# Index(['NOMINAL_SHARE_CAPITAL', 'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#        'ISSUED_SHARE_CAPITAL', 'PAID_UP_CAPITAL', 'GENERAL_RESERVE',
#        'INVESTMENT_FLUCTUATION_RESERVE', 'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#        'ALL_OTHER_RESERVES', 'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#        'UNDERWRITING_PROVISIONS', 'LONG_TERM_LIABILITIES',
#        'CURRENT_LIABLITIES', 'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#        'LAND_&_BUILDINGS', 'INVESTMENT_PROPERTY', 'OTHER_FIXED_ASSETS',
#        'KENYA_GOVT._SECURITIES', 'LOCAL_GOVT._AUTHORITY_SECURITIES',
#        'OTHER_SECURITIES', 'DEBENTURES_(QUOTED_&_UNQUOTED)',
#        'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)', 'INVESTMENT_IN_SUBSIDIARY',
#        'UNQUOTED_ORDINARY_SHARES', 'QUOTED_ORDINARY_SHARES',
#        'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)', 'UNSECURED_LOANS',
#        'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)', 'OTHER_INVESTMENTS',
#        'OUTSTANDING_PREMIUMS', 'AMOUNTS_DUE_FROM_RE_INSURERS', 'CASH',
#        'OTHER_CURRENT_ASSETS', 'INTANGIBLE_ASSETS', 'TOTAL_ASSETS',
#        'AMOUNTS_IN_'000'_KES'],
#       dtype='object', name='ITEM')
# Index(['NOMINAL_SHARE_CAPITAL', 'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#        'ISSUED_SHARE_CAPITAL', 'PAID_UP_CAPITAL', 'GENERAL_RESERVE',
#        'INVESTMENT_FLUCTUATION_RESERVE', 'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#        'ALL_OTHER_RESERVES', 'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#        'UNDERWRITING_PROVISIONS', 'LONG_TERM_LIABILITIES',
#        'CURRENT_LIABLITIES', 'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#        'LAND_&_BUILDINGS', 'INVESTMENT_PROPERTY', 'OTHER_FIXED_ASSETS',
#        'KENYA_GOVT._SECURITIES', 'LOCAL_GOVT._AUTHORITY_SECURITIES',
#        'OTHER_SECURITIES', 'DEBENTURES_(QUOTED_&_UNQUOTED)',
#        'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)', 'INVESTMENT_IN_SUBSIDIARY',
#        'UNQUOTED_ORDINARY_SHARES', 'QUOTED_ORDINARY_SHARES',
#        'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)', 'UNSECURED_LOANS',
#        'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)', 'OTHER_INVESTMENTS',
#        'OUTSTANDING_PREMIUMS', 'AMOUNTS_DUE_FROM_RE_INSURERS', 'CASH',
#        'OTHER_CURRENT_ASSETS', 'INTANGIBLE_ASSETS', 'TOTAL_ASSETS',
#        'AMOUNTS_IN_'000'_KES'],
#       dtype='object', name='ITEM')
# Index(['NOMINAL_SHARE_CAPITAL', 'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#        'ISSUED_SHARE_CAPITAL', 'PAID_UP_CAPITAL', 'GENERAL_RESERVE',
#        'INVESTMENT_FLUCTUATION_RESERVE', 'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#        'ALL_OTHER_RESERVES', 'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#        'UNDERWRITING_PROVISIONS', 'LONG_TERM_LIABILITIES',
#        'CURRENT_LIABLITIES', 'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#        'LAND_&_BUILDINGS', 'INVESTMENT_PROPERTY', 'OTHER_FIXED_ASSETS',
#        'KENYA_GOVT._SECURITIES', 'LOCAL_GOVT._AUTHORITY_SECURITIES',
#        'OTHER_SECURITIES', 'DEBENTURES_(QUOTED_&_UNQUOTED)',
#        'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)', 'INVESTMENT_IN_SUBSIDIARY',
#        'UNQUOTED_ORDINARY_SHARES', 'QUOTED_ORDINARY_SHARES',
#        'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)', 'UNSECURED_LOANS',
#        'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)', 'OTHER_INVESTMENTS',
#        'OUTSTANDING_PREMIUMS', 'AMOUNTS_DUE_FROM_RE_INSURERS', 'CASH',
#        'OTHER_CURRENT_ASSETS', 'INTANGIBLE_ASSETS', 'TOTAL_ASSETS',
#        'AMOUNTS_IN_'000'_KES'],
#       dtype='object', name='ITEM')
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID_UP_CAPITAL',
#                                      'GENERAL_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#                   'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                       'DEBENTURES_(QUOTED_&_UNQUOTED)',
#                'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                             'UNQUOTED_ORDINARY_SHARES',
#                               'QUOTED_ORDINARY_SHARES',
#           'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE_INSURERS',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                           'FIGURES_IN_THOUSANDS_KSHS.',
#                                                    nan],
#       dtype='object', name='ITEM')
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID_UP_CAPITAL',
#                                      'GENERAL_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#                   'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                       'DEBENTURES_(QUOTED_&_UNQUOTED)',
#                'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                             'UNQUOTED_ORDINARY_SHARES',
#                               'QUOTED_ORDINARY_SHARES',
#           'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE_INSURERS',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                           'FIGURES_IN_THOUSANDS_KSHS.',
#                                                    nan],
#       dtype='object', name='ITEM')

# %%
new_df4.columns
# Out:
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID_UP_CAPITAL',
#                                    'STATUTORY_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#             'UNAPPRTD_SURPLUS/RETAINED_EARNINGS_(NET)',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID_UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID_UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                             'UNQUOTED_ORDINARY_SHARES',
#                               'QUOTED_ORDINARY_SHARES',
#          'SECURED_LOANS_(INCL.LOANS_ON_LIFE_POLICIES)',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE_INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan,
#                                      'GENERAL_RESERVE',
#                   'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                       'DEBENTURES_(QUOTED_&_UNQUOTED)',
#                'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)',
#           'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)',
#                                 'AMOUNTS_IN_'000'_KES',
#                           'FIGURES_IN_THOUSANDS_KSHS.'],
#       dtype='object', name='ITEM')

# %%
new_df4.to_csv("Life_BS_12_10.csv")

# %% [markdown]
# ### agregating P/L for life insurance firms

# %%
### only works for 2019 to 2017 since they were already in excel format

files= ["2020-Annual-Insurance-Industry-Statistics(1).xls","2019 Annual Insurance Industry Statistics.xlsm","2018 Annual Statistics 28062019.xls","2017-Annual-Insurance-Statistics-Uploaded.xlsm"]
p_l_b1= pd.DataFrame()
c=0
for fil in files:
    c+=1
    f1 = pd.ExcelFile(fil)
    ## reading the specific sheets
    sheet1= pd.read_excel(f1,"APPENDIX 2",header=3)
    ### dropping the unnamed column
    sheet1.drop("Unnamed: 0",axis=1,inplace=True)
    ### concatinating the data sheets
    p_l_b1 = pd.concat([p_l_b1,sheet1])

# %%
p_l_b1.to_csv("p_l_life_20_17.csv")

# %% [markdown]
# ## P/L for pdf to excel converted files

# %%
files2= ["Annual-_Industry_Report_2016.xlsx","Annual Report 2015.xlsx","Annual-Report-2014-12.10.2015-Final.xlsx","Latest 2013 IRA Annual Report.xlsx"]
pages=[["Table 61"],["Table 57"],["Table 30"],["Table 34"]]
p_l_b2= pd.DataFrame()
for filz,page in zip(files2,pages):
    f2 = pd.ExcelFile(filz)
    ## reading the specific sheets
    for p in page:
        sheet=  pd.read_excel(f2,p,header=1)
        sheet.columns=sheet.columns.str.upper()
        sheet_t = sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        p_l_b2 = pd.concat([p_l_b2,sheet_t])

# %%
p_l_b2.to_csv("p_l_b2_life_2016_2013.csv")

# %% [markdown]
# ## P/L  batch 3 2011- 2006 agregate both gen and life insurance orgs

# %% [markdown]
# ### 2006-2009

# %%
files3= ["Annual_Report_Year_2006.xlsx","2007 Annual Report.xlsx","2009 Annual Report.xlsx"]
pages3=[["Table 31"],["Table 38"],["Table 38"]]
c=1
p_l_b3= pd.DataFrame()
for fil3,page in zip(files3,pages3):
    f3 = pd.ExcelFile(fil3)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f3,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("NAME OF INSURER",inplace=True)
            sheet_t = sheet
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            p_l_b3 = pd.concat([p_l_b3,sheet_t])
        except KeyError:
            sheet=  pd.read_excel(f3,p,header=3)
            # sheet.columns=sheet.columns.str.upper()
            #sheet.set_index("NAME OF INSURER",inplace=True)
            # sheet_t = sheet
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            p_l_b3 = pd.concat([p_l_b3,sheet_t])
            
        print(sheet_t.columns)
# Out:
# Index(['NO.', 'PROFIT/LOSS_TRANSFERRED_FROM_REVENUE', 'INVESTMENT_INCOME',
#        'SHARE_IN_MOTOR_POOL', 'OTHER_INCOMES', 'MANAGEMENT_EXPENSES',
#        'OTHER_EXPENSES', 'PROVISION_FOR_TAXATION',
#        'PROFIT_OR_LOSS_AFTER_TAXITION', 'UNAPPRTD_PROFIT/LOSS_B/F',
#        'TOTAL_PROFIT_AVAILABLE_FOR_DISTRIBUTION', 'TRANSFERS_TO_RESERVES',
#        'DIVIDENDS', 'OTHER_APPRTNS', 'UNAPPRTD_PROFIT/LOSS_C/F'],
#       dtype='object')
# Index(['NO.', 'PROFIT/LOSS_TRANSFERRED_FROM_REVENUE', 'INVESTMENT_INCOME',
#        'SHARE_IN_MOTOR_POOL', 'OTHER_INCOMES', 'MANAGEMENT_EXPENSES',
#        'OTHER_EXPENSES', 'PROVISION_FOR_TAXATION',
#        'PROFIT_OR_LOSS_AFTER_TAXITION', 'UNAPPRTD_PROFIT/LOSS_B/F',
#        'TOTAL_PROFIT_AVAILABLE_FOR_DISTRIBUTION', 'TRANSFERS_TO_RESERVES',
#        'DIVIDENDS', 'OTHER_APPRTNS', 'UNAPPRTD_PROFIT/LOSS_C/F'],
#       dtype='object')
# Index(['NO.', 'PROFIT/LOSS_TRANSFERRED_FROM_REVENUE', 'INVESTMENT_INCOME',
#        'SHARE_IN_MOTOR_POOL', 'OTHER_INCOMES', 'MANAGEMENT_EXPENSES',
#        'OTHER_EXPENSES', 'PROVISION_FOR_TAXATION',
#        'PROFIT_OR_LOSS_AFTER_TAXITION', 'UNAPPRTD_PROFIT/LOSS_B/F',
#        'TOTAL_PROFIT_AVAILABLE_FOR_DISTRIBUTION', 'TRANSFERS_TO_RESERVES',
#        'DIVIDENDS', 'OTHER_APPRTNS', 'UNAPPRTD_PROFIT/LOSS_C/F'],
#       dtype='object')

# %%
p_l_b3.to_csv("p_l_life_2006_2009.csv")

# %% [markdown]
# ## P/L for 2010 to 2012

# %%
files4= ["IRA Annual Report 2012(1).xlsx","IRA ANNUAL REPORT 2011 FINAL.xlsx","2010 insurance industry report.xlsx"]
pages4=[["Table 57"],["Table 26"],["Table 32"]]
c=1
p_l_11_10_df= pd.DataFrame()
for fil4,page in zip(files4,pages4):
    f4 = pd.ExcelFile(fil4)
    ## reading the specific sheets
    for p in page:
        try:

            sheet=  pd.read_excel(f4,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            #sheet.columns = sheet.columns.str.replace(' ','')
            sheet.set_index("COMPANY",inplace=True)
            sheet_t = sheet
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('- ','')
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace('  ',' ')
            sheet_t.columns = sheet_t.columns.str.replace('   ',' ')
            
            sheet_t.columns = sheet_t.columns.str.replace('/ ','/')
            sheet_t.columns = sheet_t.columns.str.replace(' S','S')
            sheet_t.columns = sheet_t.columns.str.replace('S ','S')
            sheet_t.columns = sheet_t.columns.str.replace('’','')
            sheet_t.columns = sheet_t.columns.str.replace("'","")
            sheet_t.columns = sheet_t.columns.str.replace(" L","L")
            sheet_t.columns = sheet_t.columns.str.replace('  ',' ')
            sheet_t.columns = sheet_t.columns.str.replace('M A','MA')
            sheet_t.columns = sheet_t.columns.str.replace('APPRTNS','APPROPRIATIONS')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')

            #sheet_t.columns = sheet_t.columns.str.replace('(LOSS )','LOSS')
            # sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            # sheet_t.columns = sheet_t.columns.str.replace('__','_')
            # sheet_t.columns = sheet_t.columns.str.upper()
            p_l_11_10_df = pd.concat([p_l_11_10_df,sheet_t])
        except KeyError:
            sheet=  pd.read_excel(f4,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("COMPANY",inplace=True)
            sheet_t = sheet
            sheet_t.columns = sheet_t.columns.str.strip()
            
            sheet_t.columns = sheet_t.columns.str.replace('- ','')
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace('  ',' ')
            sheet_t.columns = sheet_t.columns.str.replace('   ',' ')
            sheet_t.columns = sheet_t.columns.str.replace('/ ','/')
            sheet_t.columns = sheet_t.columns.str.replace(' S','S')
            sheet_t.columns = sheet_t.columns.str.replace('S ','S')
            sheet_t.columns = sheet_t.columns.str.replace('’','')
            sheet_t.columns = sheet_t.columns.str.replace("'","")
            sheet_t.columns = sheet_t.columns.str.replace(" L","L")
            sheet_t.columns = sheet_t.columns.str.replace('  ',' ')
            sheet_t.columns = sheet_t.columns.str.replace('M A','MA')
            sheet_t.columns = sheet_t.columns.str.replace('APPRTNS','APPROPRIATIONS')
            
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')

            #sheet_t.columns = sheet_t.columns.str.replace(''','')
            #sheet_t.columns = sheet_t.columns.str.replace('(LOSS )','LOSS')
            # sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            # sheet_t.columns = sheet_t.columns.str.replace('__','_')
            # sheet_t.columns = sheet_t.columns.str.upper()
            p_l_11_10_df = pd.concat([p_l_11_10_df,sheet_t])
            
        print(sheet_t.columns)
# Out:
# Index(['NO.', 'PROFIT/(LOSS)_FROM_REVENUE', 'INVESTMENT_INCOME',
#        'OTHER_INCOMES', 'MANAGEMENT_EXPENSES', 'OTHER_EXPENSES',
#        'PROFIT/(LOSS)_BEFORE_TAXATION', 'PROVISION_FOR_TAXATION',
#        'PROFIT/(LOSS)_AFTER_TAXATION', 'UNAPPRTD_PROFIT/(LOSS)_B/F',
#        'TRANSFER_TO_RESERVE', 'DIVIDEND', 'OTHER_APPROPRIATIONS',
#        'UNAPPRRTD_PROFIT/(LOSS)_C/F'],
#       dtype='object')
# Index(['UNNAMED:_0', 'PROFIT/(LOSS)_FROM_REVENUE', 'INVESTMENT_INCOME',
#        'OTHER_INCOMES', 'MANAGEMENT_EXPENSES', 'OTHER_EXPENSES',
#        'PROFIT/(LOSS)_BEFORE_TAXATION', 'PROVISION_FOR_TAXATION',
#        'PROFIT/(LOSS)_AFTER_TAXATION', 'UNAPPRTD_PROFIT/(LOSS)_B/F',
#        'TRANSFER_TO_RESERVE', 'DIVIDEND', 'OTHER_APPROPRIATIONS',
#        'UNAPPRRTD_PROFIT/(LOSS)_C/F'],
#       dtype='object')
# Index(['UNNAMED:_0', 'UNNAMED:_1', 'PROFIT/(LOSS)_FROM_REVENUE',
#        'INVESTMENT_INCOME', 'OTHER_INCOMES', 'MANAGEMENT_EXPENSES',
#        'OTHER_EXPENSES', 'PROFIT/(LOSS)_BEFORE_TAXATION',
#        'PROVISION_FOR_TAXATION', 'PROFIT/(LOSS)_AFTER_TAXATION',
#        'UNAPPRTD_PROFIT/(LOSS)_B/F', 'TRANSFER_TO_RESERVE', 'DIVIDEND',
#        'OTHER_APPROPRIATIONS', 'UNAPPRRTD_PROFIT/(LOSS)_C/F'],
#       dtype='object')

# %%
p_l_11_10_df.columns
# Out:
# 16

# %%
p_l_11_10_df.to_csv("p_l_12_10_life.csv")

# %% [markdown]
# # GENERAL INSURANCE

# %% [markdown]
# ## 2019 -2017

# %%
### only works for 2019 to 2017 since they were already in excel format
files= ["2020-Annual-Insurance-Industry-Statistics(1).xls","2019 Annual Insurance Industry Statistics.xlsm","2018 Annual Statistics 28062019.xls","2017-Annual-Insurance-Statistics-Uploaded.xlsm"]
gen_df= pd.DataFrame()
c=0
for fil in files:
    c+=1
    f1 = pd.ExcelFile(fil)
    ## reading the specific sheets
    sheet1= pd.read_excel(f1,"APPENDIX 5 I",header=2)
    sheet2 = pd.read_excel(f1,"APPENDIX 5 II",header=4)
    sheet3 = pd.read_excel(f1,"APPENDIX 5 III",header=4)
    sheet4 = pd.read_excel(f1,"APPENDIX5 IV",header=4)
    ### dropping the unnamed column
    sheet1.drop("Unnamed: 0",axis=1,inplace=True)
    sheet2.drop("Unnamed: 0",axis=1,inplace=True)
    sheet3.drop("Unnamed: 0",axis=1,inplace=True)
    sheet4.drop("Unnamed: 0",axis=1,inplace=True)
    ### setting the df index
    sheet1.set_index("Company",inplace=True)
    sheet2.set_index("Company",inplace=True)
    sheet3.set_index("Company",inplace=True)
    sheet4.set_index("Company",inplace=True)

    # ### concatinating the data sheets
    gen_df = pd.concat([gen_df,sheet1.T,sheet2.T,sheet3.T])

# %%
gen_df.to_csv("General_20_17_b_l.csv")

# %% [markdown]
# ## 2016 -2013

# %%
page_list16 = []
for i in range(66,70):
    page_list16.append("Table "+str(i))

# %%
page_list15 = []
for i in range(62,66):
    page_list15.append("Table "+str(i))

# %%
page_list14 = []
for i in range(35,39):
    page_list14.append("Table "+str(i))

# %%
page_list13 = []
for i in range(39,43):
    page_list13.append("Table "+str(i))

# %%
files2= ["Annual-_Industry_Report_2016.xlsx","Annual Report 2015.xlsx","Annual-Report-2014-12.10.2015-Final.xlsx","Latest 2013 IRA Annual Report.xlsx"]
pages=[page_list16,page_list15,page_list14,page_list13]
c=1
General_16_13_b_s= pd.DataFrame()
for filz,page in zip(files2,pages):
    f2 = pd.ExcelFile(filz)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f2,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("COMPANY",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.upper()
            General_16_13_b_s = pd.concat([General_16_13_b_s,sheet_t])
        except KeyError:
            sheet=  pd.read_excel(f2,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("COMPANY",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.upper()
            General_16_13_b_s = pd.concat([General_16_13_b_s,sheet_t])
            
            print(sheet_t.columns)
# Out:
# Index(['SHARE CAPITAL', 'SHARE PREMIUM', 'REVALUATION RESERVES',
#        'STATUTORY RESERVES', 'RETAINED EARNINGS', 'OTHER RESERVES',
#        'TOTAL EQUITY', 'UNDERWRITING PROVISIONS',
#        'ACTUARIAL CONTRACT LIABILITIES', 'LONGTERM LIABILITIES',
#        'CURRENT LIABILITIES', 'TOTAL EQUITY AND LIABILITIES',
#        'LAND AND BUILDINGS', 'INVESTMENT PROPERTY', 'OTHER FIXED ASSETS',
#        'GOVERNMENT SECURITIES', 'OTHER SECURITIES',
#        'INVESTMENT IN RELATED COMPANIES', 'CORPORATE BONDS',
#        'COMMERCIAL PAPERS', 'DEBENTURES', 'ORDINARY SHARES QUOTED',
#        'ORDINARY SHARES UNQUOTED', 'PREFERENCE SHARES QUOTED',
#        'PREFERENCE SHARES UNQUOTED', 'LOANS SECURED & UNSECURED', 'MORTGAGES',
#        'TERM DEPOSITS', 'CASH AND CASH BALANCES', 'OUTSTANDING PREMIUMS',
#        'OTHER RECEIVABLES', 'OTHER ASSETS', 'INTANGIBLE ASSETS',
#        'TOTAL ASSETS',
#        'AMOUNTS IN THOUSAND SHILLINGS                                                                                                                                                                                                                                                           CONTINUED NEXT PAGE'],
#       dtype='object', name='COMPANY')
# Index(['SHARE CAPITAL', 'SHARE PREMIUM', 'REVALUATION RESERVES',
#        'STATUTORY RESERVES', 'RETAINED EARNINGS', 'OTHER RESERVES',
#        'TOTAL EQUITY', 'UNDERWRITING PROVISIONS',
#        'ACTUARIAL CONTRACT LIABILITIES', 'LONGTERM LIABILITIES',
#        'CURRENT LIABILITIES', 'TOTAL EQUITY AND LIABILITIES',
#        'LAND AND BUILDINGS', 'INVESTMENT PROPERTY', 'OTHER FIXED ASSETS',
#        'GOVERNMENT SECURITIES', 'OTHER SECURITIES',
#        'INVESTMENT IN RELATED COMPANIES', 'CORPORATE BONDS',
#        'COMMERCIAL PAPERS', 'DEBENTURES', 'ORDINARY SHARES QUOTED',
#        'ORDINARY SHARES UNQUOTED', 'PREFERENCE SHARES QUOTED',
#        'PREFERENCE SHARES UNQUOTED', 'LOANS SECURED & UNSECURED', 'MORTGAGES',
#        'TERM DEPOSITS', 'CASH AND CASH BALANCES', 'OUTSTANDING PREMIUMS',
#        'OTHER RECEIVABLES', 'OTHER ASSETS', 'INTANGIBLE ASSETS',
#        'TOTAL ASSETS',
#        'AMOUNTS IN THOUSAND SHILLINGS                                                                                                                                                                                                                                                                      CONTINUED NEXT PAGE'],
#       dtype='object', name='COMPANY')
# Index(['SHARE CAPITAL', 'SHARE PREMIUM', 'REVALUATION RESERVES',
#        'STATUTORY RESERVES', 'RETAINED EARNINGS', 'OTHER RESERVES',
#        'TOTAL EQUITY', 'UNDERWRITING PROVISIONS',
#        'ACTUARIAL CONTRACT LIABILITIES', 'LONGTERM LIABILITIES',
#        'CURRENT LIABILITIES', 'TOTAL EQUITY AND LIABILITIES',
#        'LAND AND BUILDINGS', 'INVESTMENT PROPERTY', 'OTHER FIXED ASSETS',
#        'GOVERNMENT SECURITIES', 'OTHER SECURITIES',
#        'INVESTMENT IN RELATED COMPANIES', 'CORPORATE BONDS',
#        'COMMERCIAL PAPERS', 'DEBENTURES', 'ORDINARY SHARES QUOTED',
#        'ORDINARY SHARES UNQUOTED', 'PREFERENCE SHARES QUOTED',
#        'PREFERENCE SHARES UNQUOTED', 'LOANS SECURED & UNSECURED', 'MORTGAGES',
#        'TERM DEPOSITS', 'CASH AND CASH BALANCES', 'OUTSTANDING PREMIUMS',
#        'OTHER RECEIVABLES', 'OTHER ASSETS', 'INTANGIBLE ASSETS',
#        'TOTAL ASSETS', 'AMOUNTS IN THOUSAND SHILLINGS'],
#       dtype='object', name='COMPANY')
# Index(['SHARE CAPITAL', 'SHARE PREMIUM', 'REVALUATION RESERVES',
#        'STATUTORY RESERVES', 'RETAINED EARNINGS', 'OTHER RESERVES',
#        'TOTAL EQUITY', 'UNDERWRITING PROVISIONS',
#        'ACTUARIAL CONTRACT LIABILITIES', 'LONGTERM LIABILITIES',
#        'CURRENT LIABILITIES', 'TOTAL EQUITY AND LIABILITIES',
#        'LAND AND BUILDINGS', 'INVESTMENT PROPERTY', 'OTHER FIXED ASSETS',
#        'GOVERNMENT SECURITIES', 'OTHER SECURITIES',
#        'INVESTMENT IN RELATED COMPANIES', 'CORPORATE BONDS',
#        'COMMERCIAL PAPERS', 'DEBENTURES', 'ORDINARY SHARES QUOTED',
#        'ORDINARY SHARES UNQUOTED', 'PREFERENCE SHARES QUOTED',
#        'PREFERENCE SHARES UNQUOTED', 'LOANS SECURED & UNSECURED', 'MORTGAGES',
#        'TERM DEPOSITS', 'CASH AND CASH BALANCES', 'OUTSTANDING PREMIUMS',
#        'OTHER RECEIVABLES', 'OTHER ASSETS', 'INTANGIBLE ASSETS',
#        'TOTAL ASSETS',
#        'AMOUNTS IN THOUSAND SHILLINGS                                                                                                                                                                                                                                                            CONTINUED NEXT PAGE'],
#       dtype='object', name='COMPANY')
# Index(['SHARE CAPITAL', 'SHARE PREMIUM', 'REVALUATION RESERVES',
#        'STATUTORY RESERVES', 'RETAINED EARNINGS', 'OTHER RESERVES',
#        'TOTAL EQUITY', 'UNDERWRITING PROVISIONS',
#        'ACTUARIAL CONTRACT LIABILITIES', 'LONGTERM LIABILITIES',
#        'CURRENT LIABILITIES', 'TOTAL EQUITY AND LIABILITIES',
#        'LAND AND BUILDINGS', 'INVESTMENT PROPERTY', 'OTHER FIXED ASSETS',
#        'GOVERNMENT SECURITIES', 'OTHER SECURITIES',
#        'INVESTMENT IN RELATED COMPANIES', 'CORPORATE BONDS',
#        'COMMERCIAL PAPERS', 'DEBENTURES', 'ORDINARY SHARES QUOTED',
#        'ORDINARY SHARES UNQUOTED', 'PREFERENCE SHARES QUOTED',
#        'PREFERENCE SHARES UNQUOTED', 'LOANS SECURED & UNSECURED', 'MORTGAGES',
#        'TERM DEPOSITS', 'CASH AND CASH BALANCES', 'OUTSTANDING PREMIUMS',
#        'OTHER RECEIVABLES', 'OTHER ASSETS', 'INTANGIBLE ASSETS',
#        'TOTAL ASSETS',
#        'AMOUNTS IN THOUSAND SHILLINGS                                                                                                                                                                                                                                                               CONTINUED NEXT PAGE'],
#       dtype='object', name='COMPANY')
# Index(['SHARE CAPITAL', 'SHARE PREMIUM', 'REVALUATION RESERVES',
#        'STATUTORY RESERVES', 'RETAINED EARNINGS', 'OTHER RESERVES',
#        'TOTAL EQUITY', 'UNDERWRITING PROVISIONS',
#        'ACTUARIAL CONTRACT LIABILITIES', 'LONGTERM LIABILITIES',
#        'CURRENT LIABILITIES', 'TOTAL EQUITY AND LIABILITIES',
#        'LAND AND BUILDINGS', 'INVESTMENT PROPERTY', 'OTHER FIXED ASSETS',
#        'GOVERNMENT SECURITIES', 'OTHER SECURITIES',
#        'INVESTMENT IN RELATED COMPANIES', 'CORPORATE BONDS',
#        'COMMERCIAL PAPERS', 'DEBENTURES', 'ORDINARY SHARES QUOTED',
#        'ORDINARY SHARES UNQUOTED', 'PREFERENCE SHARES QUOTED',
#        'PREFERENCE SHARES UNQUOTED', 'LOANS SECURED & UNSECURED', 'MORTGAGES',
#        'TERM DEPOSITS', 'CASH AND CASH BALANCES', 'OUTSTANDING PREMIUMS',
#        'OTHER RECEIVABLES', 'OTHER ASSETS', 'INTANGIBLE ASSETS',
#        'TOTAL ASSETS', 'AMOUNTS IN THOUSAND SHILLINGS'],
#       dtype='object', name='COMPANY')
# Index(['SHARE CAPITAL', 'SHARE PREMIUM', 'REVALUATION RESERVES',
#        'STATUTORY RESERVES', 'RETAINED EARNINGS', 'OTHER RESERVES',
#        'TOTAL EQUITY', 'UNDERWRITING PROVISIONS',
#        'ACTUARIAL CONTRACT LIABILITIES', 'LONGTERM LIABILITIES',
#        'CURRENT LIABILITIES', 'TOTAL EQUITY AND LIABILITIES',
#        'LAND AND BUILDINGS', 'INVESTMENT PROPERTY', 'OTHER FIXED ASSETS',
#        'GOVERNMENT SECURITIES', 'OTHER SECURITIES',
#        'INVESTMENT IN RELATED COMPANIES', 'CORPORATE BONDS',
#        'COMMERCIAL PAPERS', 'DEBENTURES', 'ORDINARY SHARES QUOTED',
#        'ORDINARY SHARES UNQUOTED', 'PREFERENCE SHARES QUOTED',
#        'PREFERENCE SHARES UNQUOTED', 'LOANS SECURED & UNSECURED', 'MORTGAGES',
#        'TERM DEPOSITS', 'CASH AND CASH BALANCES', 'OUTSTANDING PREMIUMS',
#        'OTHER RECEIVABLES', 'OTHER ASSETS', 'INTANGIBLE ASSETS',
#        'TOTAL ASSETS',
#        'AMOUNTS IN THOUSAND SHILLINGS                                                                                                                                                                                                                                                                                                    CONTINUED NEXT PAGE'],
#       dtype='object', name='COMPANY')

# %%
len(General_16_13_b_s.columns)
# Out:
# 44

# %%
General_16_13_b_s.to_csv("General_bs_16_13.csv")

# %% [markdown]
# ## 2006 - 2009

# %%
page_list06 = []
for i in range(32,35):
    page_list06.append("Table "+str(i))

# %%
page_list07 = []
for i in range(43,47):
    page_list07.append("Table "+str(i))

# %%
page_list10 = []
for i in range(36,40):
    page_list10.append("Table "+str(i))

# %%
files3= ["Annual_Report_Year_2006.xlsx","2007 Annual Report.xlsx","2009 Annual Report.xlsx"]
pages3=[page_list06,page_list07,page_list09]
c=1
General_BS_09_06_df= pd.DataFrame()
for fil3,page in zip(files3,pages3):
    f3 = pd.ExcelFile(fil3)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f3,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            #sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            General_BS_09_06_df = pd.concat([General_BS_09_06_df,sheet_t])
        except KeyError:
            sheet=  pd.read_excel(f3,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            #sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            General_BS_09_06_df = pd.concat([General_BS_09_06_df,sheet_t])
            
        print(len(sheet_t.columns))
# Out:
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 34
# 34
# 34
# 34

# %%
General_BS_09_06_df.to_csv("General_BS_09_06.csv")

# %% [markdown]
# ## 2011 and 2010

# %%
page_list10 = []
for i in range(36,40):
    page_list10.append("Table "+str(i))

# %%
page_list11 = []
for i in range(31,35):
    page_list11.append("Table "+str(i))

# %%
files4= ["2010 insurance industry report.xlsx"]
pages4=[page_list10]
c=1
new_df4= pd.DataFrame()
for fil4,page in zip(files4,pages4):
    f4 = pd.ExcelFile(fil4)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f4,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            #sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            #sheet_t.reset_index(inplace=True)
            #print(sheet_t.index)
            new_df4 = pd.concat([new_df4,sheet_t])
        except( KeyError, IndexError)as e:
            sheet=  pd.read_excel(f4,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            #sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            new_df4 = pd.concat([new_df4,sheet_t])
        print(sheet_t.index)
            
        #print(len(sheet_t.columns))
# Out:
# Index(['NO.', 'UNNAMED:_1', 'CHARTIS_(K)', 'AMACO', 'APA', 'BLUE_SSHIELD',
#        'BRITAK', 'CANNON', 'CFC_LIFE', 'CON_CORD', 'COOP_ERATIVE',
#        'CORPO_RATE'],
#       dtype='object')
# Index(['NO.', 'UNNAMED:_1', 'DIRECTLINE', 'EAST_AFRICA_RE', 'FIDELITY_SHIELD',
#        'FIRST_ASSURANCE', 'GATEWAY', 'GEMINIA', 'GA', 'HERITAGE', 'ICEA',
#        'INTRA_AFRICA'],
#       dtype='object')
# Index(['NO.', 'UNNAMED:_1', 'INVES_CO', 'JUBILEE', 'KENIN_DIA', 'KENYA_ORIENT',
#        'KENYA_RE', 'KENYAN_ALLIANCE', 'LION_OF_KENYA', 'MADISON', 'MAYFAIR',
#        'MER_CANTILE'],
#       dtype='object')
# Index(['NO.', 'UNNAMED:_1', 'OCCIDENTAL', 'PACIS', 'PHOENIX', 'PIONEER',
#        'REAL', 'TAUSI', 'THE_MONARCH', 'TRIDENT', 'UAP_IN_SURANCE', 'TOTAL'],
#       dtype='object')

# %%
new_df4.to_csv("General_BS_10.csv")

# %% [markdown]
# # 2011

# %%
files4= ["IRA ANNUAL REPORT 2011 FINAL.xlsx"]
pages4=[["Table 31","Table 33"]]
c=1
Gen_BS_2011_1= pd.DataFrame()
for fil4,page in zip(files4,pages4):
    f4 = pd.ExcelFile(fil4)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f4,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            #print(sheet_t.head())
            Gen_BS_2011_1 = pd.concat([Gen_BS_2011_1,sheet_t])
        except( KeyError, IndexError)as e:
            sheet=  pd.read_excel(f4,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            Gen_BS_2011_1 = pd.concat([Gen_BS_2011_1,sheet_t])
            #print(sheet_t.head())
        print(sheet_t.columns)
# Out:
# Index(['NOMINAL_SHARE_CAPITAL', 'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#        'ISSUED_SHARE_CAPITAL', 'PAID-UP_CAPITAL', 'GENERAL_RESERVE',
#        'INVESTMENT_FLUCTUATION_RESERVE', 'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#        'ALL_OTHER_RESERVES', 'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#        'UNDERWRITING_PROVISIONS', 'LONG_TERM_LIABILITIES',
#        'CURRENT_LIABLITIES', 'TOTAL_PAID-UP_CAPITAL,_RES_ERVES_&_LIABILITIES',
#        'LAND_&_BUILDINGS', 'INVESTMENT_PROPERTY', 'OTHER_FIXED_ASSETS',
#        'KENYA_GOVT._SECURITIES', 'LOCAL_GOVT._AUTHORITY_SECURITIES',
#        'OTHER_SECURITIES', 'DEBENTURES_(QUOTED_&_UNQUOTED)',
#        'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)', 'INVESTMENT_IN_SUBSIDIARY',
#        'QUOTED_ORDINARY_SHARES', 'UNQUOTED_ORDINARY_SHARES',
#        'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)', 'UNSECURED_LOANS',
#        'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)', 'OTHER_INVESTMENTS',
#        'OUTSTANDING_PREMIUMS', 'AMOUNTS_DUE_FROM_RE-INSURERS', 'CASH',
#        'OTHER_CURRENT_ASSETS', 'INTANGIBLE_ASSETS', 'TOTAL_ASSETS',
#        'AMOUNTS_IN_'000'_KES'],
#       dtype='object', name='ITEM')
# Index(['NOMINAL_SHARE_CAPITAL', 'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#        'ISSUED_SHARE_CAPITAL', 'PAID-UP_CAPITAL', 'GENERAL_RESERVE',
#        'INVESTMENT_FLUCTUATION_RESERVE', 'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#        'ALL_OTHER_RESERVES', 'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#        'UNDERWRITING_PROVISIONS', 'LONG_TERM_LIABILITIES',
#        'CURRENT_LIABLITIES', 'TOTAL_PAID-UP_CAPITAL,_RES_ERVES_&_LIABILITIES',
#        'LAND_&_BUILDINGS', 'INVESTMENT_PROPERTY', 'OTHER_FIXED_ASSETS',
#        'KENYA_GOVT._SECURITIES', 'LOCAL_GOVT._AUTHORITY_SECURITIES',
#        'OTHER_SECURITIES', 'DEBENTURES_(QUOTED_&_UNQUOTED)',
#        'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)', 'INVESTMENT_IN_SUBSIDIARY',
#        'QUOTED_ORDINARY_SHARES', 'UNQUOTED_ORDINARY_SHARES',
#        'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)', 'UNSECURED_LOANS',
#        'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)', 'OTHER_INVESTMENTS',
#        'OUTSTANDING_PREMIUMS', 'AMOUNTS_DUE_FROM_RE-INSURERS', 'CASH',
#        'OTHER_CURRENT_ASSETS', 'INTANGIBLE_ASSETS', 'TOTAL_ASSETS',
#        'AMOUNTS_IN_'000'_KES'],
#       dtype='object', name='ITEM')

# %%
Gen_BS_2011_1.to_csv("Gen_BS_2011_1.csv")

# %%
files4= ["IRA ANNUAL REPORT 2011 FINAL.xlsx"]
pages4=[["Table 32"]]
c=1
Gen_BS_2011_2= pd.DataFrame()
for fil4,page in zip(files4,pages4):
    f4 = pd.ExcelFile(fil4)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f4,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            #print(sheet_t.head())
            Gen_BS_2011_2 = pd.concat([Gen_BS_2011_2,sheet_t])
        except( KeyError, IndexError)as e:
            sheet=  pd.read_excel(f4,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            Gen_BS_2011_2 = pd.concat([Gen_BS_2011_2,sheet_t])
            #print(sheet_t.head())
        print(sheet_t.columns)
# Out:
# Index([                         'NOMINAL_SHARE_CAPITAL',
#               'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                  'ISSUED_SHARE_CAPITAL',
#                                       'PAID-UP_CAPITAL',
#                                       'GENERAL_RESERVE',
#                        'INVESTMENT_FLUCTUATION_RESERVE',
#                    'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                    'ALL_OTHER_RESERVES',
#                      'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#                               'UNDERWRITING_PROVISIONS',
#                                 'LONG_TERM_LIABILITIES',
#                                    'CURRENT_LIABLITIES',
#        'TOTAL_PAID-UP_CAPITAL,_RES_ERVES_&_LIABILITIES',
#                                      'LAND_&_BUILDINGS',
#                                   'INVESTMENT_PROPERTY',
#                                    'OTHER_FIXED_ASSETS',
#                                'KENYA_GOVT._SECURITIES',
#                      'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                      'OTHER_SECURITIES',
#                        'DEBENTURES_(QUOTED_&_UNQUOTED)',
#                 'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)',
#                              'INVESTMENT_IN_SUBSIDIARY',
#                                'QUOTED_ORDINARY_SHARES',
#                              'UNQUOTED_ORDINARY_SHARES',
#            'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)',
#                                       'UNSECURED_LOANS',
#            'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                     'OTHER_INVESTMENTS',
#                                  'OUTSTANDING_PREMIUMS',
#                          'AMOUNTS_DUE_FROM_RE-INSURERS',
#                                                  'CASH',
#                                  'OTHER_CURRENT_ASSETS',
#                                     'INTANGIBLE_ASSETS',
#                                          'TOTAL_ASSETS',
#                                  'AMOUNTS_IN_'000'_KES',
#                                                     nan,
#                                                     nan,
#                                                     nan,
#                                                     nan,
#                                                     nan],
#       dtype='object', name='ITEM')

# %%
Gen_BS_2011_2.to_csv("Gen_BS_2011_2.csv")

# %%
files4= ["IRA ANNUAL REPORT 2011 FINAL.xlsx"]
pages4=[["Table 34"]]
c=1
Gen_BS_2011_3= pd.DataFrame()
for fil4,page in zip(files4,pages4):
    f4 = pd.ExcelFile(fil4)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f4,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            #print(sheet_t.head())
            Gen_BS_2011_3 = pd.concat([Gen_BS_2011_3,sheet_t])
        except( KeyError, IndexError)as e:
            sheet=  pd.read_excel(f4,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            Gen_BS_2011_3 = pd.concat([Gen_BS_2011_3,sheet_t])
            #print(sheet_t.head())
        print(sheet_t.columns)
# Out:
# Index([                         'NOMINAL_SHARE_CAPITAL',
#               'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                  'ISSUED_SHARE_CAPITAL',
#                                       'PAID-UP_CAPITAL',
#                                       'GENERAL_RESERVE',
#                        'INVESTMENT_FLUCTUATION_RESERVE',
#                    'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                    'ALL_OTHER_RESERVES',
#                      'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#                               'UNDERWRITING_PROVISIONS',
#                                 'LONG_TERM_LIABILITIES',
#                                    'CURRENT_LIABLITIES',
#        'TOTAL_PAID-UP_CAPITAL,_RES_ERVES_&_LIABILITIES',
#                                      'LAND_&_BUILDINGS',
#                                   'INVESTMENT_PROPERTY',
#                                    'OTHER_FIXED_ASSETS',
#                                'KENYA_GOVT._SECURITIES',
#                      'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                      'OTHER_SECURITIES',
#                        'DEBENTURES_(QUOTED_&_UNQUOTED)',
#                 'PREFERENCE_SHARES_(QUOTED_&_UNQUOTED)',
#                              'INVESTMENT_IN_SUBSIDIARY',
#                                'QUOTED_ORDINARY_SHARES',
#                              'UNQUOTED_ORDINARY_SHARES',
#            'SECURED_LOANS_(INCLUDING_LOAN_OF_POLICIES)',
#                                       'UNSECURED_LOANS',
#            'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                     'OTHER_INVESTMENTS',
#                                  'OUTSTANDING_PREMIUMS',
#                          'AMOUNTS_DUE_FROM_RE-INSURERS',
#                                                  'CASH',
#                                  'OTHER_CURRENT_ASSETS',
#                                     'INTANGIBLE_ASSETS',
#                                          'TOTAL_ASSETS',
#                                  'AMOUNTS_IN_'000'_KES',
#                                                     nan,
#                                                     nan],
#       dtype='object', name='ITEM')

# %%
Gen_BS_2011_3.to_csv("Gen_BS_2011_3.csv")

# %% [markdown]
# ## 2012

# %%
page_list12= []
for i in range(62,66):
    page_list12.append("Table "+str(i))

# %%
files4= ["IRA Annual Report 2012(1).xlsx"]
pages4=[page_list12]
c=1
Gen_BS_2011_2= pd.DataFrame()
for fil4,page in zip(files4,pages4):
    f4 = pd.ExcelFile(fil4)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f4,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns= sheet_t.columns.str.replace('   ',' ')
            sheet_t.columns= sheet_t.columns.str.replace('  ',' ')
            sheet_t.columns= sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            # sheet_t.columns = sheet_t.columns.str.replace('.','_')
           
            # sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            # sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            # sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            # sheet_t.columns = sheet_t.columns.str.replace('__','_')
            # sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            #print(sheet_t.head())
            Gen_BS_2011_2 = pd.concat([Gen_BS_2011_2,sheet_t])
        except( KeyError, IndexError)as e:
            sheet=  pd.read_excel(f4,p,header=2)
            sheet.columns=sheet.columns.str.upper()
            sheet.set_index("ITEM",inplace=True)
            sheet_t = sheet.T
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns= sheet_t.columns.str.replace('   ',' ')
            sheet_t.columns= sheet_t.columns.str.replace('  ',' ')
            sheet_t.columns= sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            #sheet_t.index = sheet_t.index.str.replace('.',' ')
            #sheet_t.index = sheet_t.index.str.replace('-',' ')
            # sheet_t.columns = sheet_t.columns.str.replace(' ','')
            # sheet_t.columns = sheet_t.columns.str.replace('-','_')
            # sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            # sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            # sheet_t.columns = sheet_t.columns.str.replace('__','_')
            # sheet_t.columns = sheet_t.columns.str.upper()
            sheet_t.index = sheet_t.index.str.replace('-',' ')
            sheet_t.index = sheet_t.index.str.replace('\n',' ')
            sheet_t.index = sheet_t.index.str.replace(' ','_')
            sheet_t.index = sheet_t.index.str.replace('__','_')
            Gen_BS_2011_2 = pd.concat([Gen_BS_2011_2,sheet_t])
            #print(sheet_t.head())
        print(sheet_t.columns)
# Out:
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID-UP_CAPITAL',
#                                      'GENERAL_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#                   'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID-UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                               'QUOTED_ORDINARY_SHARES',
#                             'UNQUOTED_ORDINARY_SHARES',
#                                        'SECURED_LOANS',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE-INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan],
#       dtype='object', name='ITEM')
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID-UP_CAPITAL',
#                                      'GENERAL_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#                   'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID-UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                               'QUOTED_ORDINARY_SHARES',
#                             'UNQUOTED_ORDINARY_SHARES',
#                                        'SECURED_LOANS',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE-INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan],
#       dtype='object', name='ITEM')
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID-UP_CAPITAL',
#                                      'GENERAL_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#                   'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID-UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                               'QUOTED_ORDINARY_SHARES',
#                             'UNQUOTED_ORDINARY_SHARES',
#                                        'SECURED_LOANS',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE-INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan],
#       dtype='object', name='ITEM')
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID-UP_CAPITAL',
#                                      'GENERAL_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#                   'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID-UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                               'QUOTED_ORDINARY_SHARES',
#                             'UNQUOTED_ORDINARY_SHARES',
#                                        'SECURED_LOANS',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE-INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan],
#       dtype='object', name='ITEM')

# %%
Gen_BS_2011_2.columns
# Out:
# Index([                        'NOMINAL_SHARE_CAPITAL',
#              'NOMINAL_VALUE_OF_UNISSUED_SHARE_CAPITAL',
#                                 'ISSUED_SHARE_CAPITAL',
#                                      'PAID-UP_CAPITAL',
#                                      'GENERAL_RESERVE',
#                       'INVESTMENT_FLUCTUATION_RESERVE',
#                   'UNAPPRTD_SURPLUS/RETAINED_EARNINGS',
#                                   'ALL_OTHER_RESERVES',
#                     'TOTAL_PAID-UP_CAPITAL_&_RESERVES',
#                              'UNDERWRITING_PROVISIONS',
#                                'LONG_TERM_LIABILITIES',
#                                   'CURRENT_LIABLITIES',
#        'TOTAL_PAID-UP_CAPITAL,_RESERVES_&_LIABILITIES',
#                                     'LAND_&_BUILDINGS',
#                                  'INVESTMENT_PROPERTY',
#                                   'OTHER_FIXED_ASSETS',
#                               'KENYA_GOVT._SECURITIES',
#                     'LOCAL_GOVT._AUTHORITY_SECURITIES',
#                                     'OTHER_SECURITIES',
#                         'DEBENTURES_QUOTED_&_UNQUOTED',
#                    'PREFERENCE_SHARES_QUOTED/UNQUOTED',
#                             'INVESTMENT_IN_SUBSIDIARY',
#                               'QUOTED_ORDINARY_SHARES',
#                             'UNQUOTED_ORDINARY_SHARES',
#                                        'SECURED_LOANS',
#                                      'UNSECURED_LOANS',
#           'DEPOSITS_(WITH_BANKS_&_OTHER_INSTITUTIONS)',
#                                    'OTHER_INVESTMENTS',
#                                 'OUTSTANDING_PREMIUMS',
#                         'AMOUNTS_DUE_FROM_RE-INSURERS',
#           'REINSURERS'_SHARE_OF_TECHNICAL_LIABILITIES',
#                                                 'CASH',
#                                 'OTHER_CURRENT_ASSETS',
#                                    'INTANGIBLE_ASSETS',
#                                         'TOTAL_ASSETS',
#                                                    nan],
#       dtype='object', name='ITEM')

# %%
Gen_BS_2011_2.to_csv("General_2012_BS.csv")

# %% [markdown]
# ## P/L for Gen Insurance

# %% [markdown]
# ## 2020-2017

# %%
files= ["2020-Annual-Insurance-Industry-Statistics(1).xls","2019 Annual Insurance Industry Statistics.xlsm","2018 Annual Statistics 28062019.xls","2017-Annual-Insurance-Statistics-Uploaded.xlsm"]
p_l_gen_19_17= pd.DataFrame()
c=0
for fil in files:
    c+=1
    f1 = pd.ExcelFile(fil)
    ## reading the specific sheets
    sheet1= pd.read_excel(f1,"APPENDIX 1",header=2)
    ### dropping the unnamed column
    sheet1.drop("Unnamed: 0",axis=1,inplace=True)
    ### concatinating the data sheets
    p_l_gen_19_17 = pd.concat([p_l_gen_19_17,sheet1])

# %%
p_l_gen_19_17.to_csv("p_l_gen_20_17.csv")

# %% [markdown]
# ## 2016-2013

# %%
files2= ["Annual-_Industry_Report_2016.xlsx","Annual Report 2015.xlsx","Annual-Report-2014-12.10.2015-Final.xlsx","Latest 2013 IRA Annual Report.xlsx"]
pages=[["Table 60"],["Table 56"],["Table 29"],["Table 33"]]
p_l_gen_16_13= pd.DataFrame()
for filz,page in zip(files2,pages):
    f2 = pd.ExcelFile(filz)
    ## reading the specific sheets
    for p in page:
        sheet=  pd.read_excel(f2,p,header=1)
        sheet.columns=sheet.columns.str.upper()
        sheet_t = sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace('- ','')
        sheet_t.columns = sheet_t.columns.str.replace('/  ','')
        sheet_t.columns = sheet_t.columns.str.replace('/ ','/')
        p_l_gen_16_13 = pd.concat([p_l_gen_16_13,sheet_t])

# %%
len(p_l_gen_16_13.columns)
# Out:
# 16

# %%
p_l_gen_16_13.to_csv("p_l_gen_16_13.csv")

# %% [markdown]
# # 2009 - 2006

# %%
files3= ["Annual_Report_Year_2006.xlsx","2007 Annual Report.xlsx","2009 Annual Report.xlsx"]
pages3=[["Table 30"],["Table 37"],["Table 37"]]
c=1
p_l_gen_09_06= pd.DataFrame()
for fil3,page in zip(files3,pages3):
    f3 = pd.ExcelFile(fil3)
    ## reading the specific sheets
    for p in page:
        try:
            sheet=  pd.read_excel(f3,p,header=1)
            sheet.columns=sheet.columns.str.upper()
            
            sheet.set_index("NAME OF INSURER",inplace=True)
            sheet_t = sheet
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            p_l_gen_09_06 = pd.concat([p_l_gen_09_06,sheet_t])
        except KeyError:
            sheet=  pd.read_excel(f3,p,header=3)
            # sheet.columns=sheet.columns.str.upper()
            #sheet.set_index("NAME OF INSURER",inplace=True)
            # sheet_t = sheet
            sheet_t.columns = sheet_t.columns.str.strip()
            sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
            sheet_t.columns = sheet_t.columns.str.replace(' ','_')
            sheet_t.columns = sheet_t.columns.str.replace('__','_')
            sheet_t.columns = sheet_t.columns.str.upper()
            p_l_gen_09_06 = pd.concat([p_l_gen_09_06,sheet_t])
            
        print(sheet_t.columns)
# Out:
# Index(['COMPANY', 'PROFIT_TRANSFERRED_FROM_REVENUE', 'INVESTMENT_INCOME',
#        'OTHER_INCOME', 'TOTAL_INCOME', 'LOSS_TRANSFERRED_FROM_REVENUE',
#        'MANAGEMENT_EXPENSES', 'TOTAL_OUTGO', 'PROFIT_/_(LOSS)_BEFORE_TAXATION',
#        'PROVISION_FOR_TAXATION', 'PROFIT/(LOSS)_AFTER_TAXATION',
#        'UNAPPROPRI-_ATED_PROFIT/_(LOSS)_BF', 'TRANSFER_TO_RESERVES',
#        'OTHER_APPROPRIA-_TIONS', 'DIVIDEND',
#        'UNAPPROPRIATED_PROFIT_/_(LOSS)_CF'],
#       dtype='object')
# Index(['COMPANY', 'PROFIT_TRANSFERRED_FROM_REVENUE', 'INVESTMENT_INCOME',
#        'OTHER_INCOME', 'TOTAL_INCOME', 'LOSS_TRANSFERRED_FROM_REVENUE',
#        'MANAGEMENT_EXPENSES', 'TOTAL_OUTGO', 'PROFIT_/_(LOSS)_BEFORE_TAXATION',
#        'PROVISION_FOR_TAXATION', 'PROFIT/(LOSS)_AFTER_TAXATION',
#        'UNAPPROPRI-_ATED_PROFIT/_(LOSS)_BF', 'TRANSFER_TO_RESERVES',
#        'OTHER_APPROPRIA-_TIONS', 'DIVIDEND',
#        'UNAPPROPRIATED_PROFIT_/_(LOSS)_CF'],
#       dtype='object')
# Index(['COMPANY', 'PROFIT_TRANSFERRED_FROM_REVENUE', 'INVESTMENT_INCOME',
#        'OTHER_INCOME', 'TOTAL_INCOME', 'LOSS_TRANSFERRED_FROM_REVENUE',
#        'MANAGEMENT_EXPENSES', 'TOTAL_OUTGO', 'PROFIT_/_(LOSS)_BEFORE_TAXATION',
#        'PROVISION_FOR_TAXATION', 'PROFIT/(LOSS)_AFTER_TAXATION',
#        'UNAPPROPRI-_ATED_PROFIT/_(LOSS)_BF', 'TRANSFER_TO_RESERVES',
#        'OTHER_APPROPRIA-_TIONS', 'DIVIDEND',
#        'UNAPPROPRIATED_PROFIT_/_(LOSS)_CF'],
#       dtype='object')

# %%
p_l_gen_09_06.to_csv("p_l_gen_09_06.csv")

# %% [markdown]
# ## Additional datasets

# %% [markdown]
# ### summary of gen business combined revenue accounts

# %% [markdown]
# ### 2020-2017

# %%
files= ["2020-Annual-Insurance-Industry-Statistics(1).xls","2019 Annual Insurance Industry Statistics.xlsm","2018 Annual Statistics 28062019.xls","2017-Annual-Insurance-Statistics-Uploaded.xlsm"]
rev_20_17= pd.DataFrame()
c=0
for fil in files:
    c+=1
    f1 = pd.ExcelFile(fil)
    ## reading the specific sheets
    sheet1= pd.read_excel(f1,"APPENDIX 36",header=3)
    ### dropping the unnamed column
    sheet1.drop("Unnamed: 1",axis=1,inplace=True)
    sheet1.drop("Unnamed: 0",axis=1,inplace=True)
    ### concatinating the data sheets
    rev_20_17 = pd.concat([rev_20_17,sheet1])

# %%
rev_20_17.head()
# Out:
#                        Company  Gross Direct Premium   \
# 0                     INSURERS                    NaN
# 1          AAR INSURANCE KENYA              5683964.0
# 2  AFRICAN MERCHANT ASSURANCE               1069484.0
# 3        AIG INSURANCE COMPANY              2977660.0
# 4    ALLIANZ INSURANCE COMPANY               929347.0
#
#    Inward Reinsurance_x000D_  Outward Reinsurance   Net Premium Written  \
# 0                        NaN                   NaN                  NaN
# 1                        0.0             1966689.0            3717275.0
# 2                        0.0              186269.0             883215.0
# 3                    68174.0             2329000.0             716834.0
# 4                        0.0              419914.0             509433.0
#
#      UPR B/F   Unexpired Risk Reserve (B/F)   UPR C/F_x000D_  \
# 0        NaN                             NaN             NaN
# 1  1494294.0                             0.0       1460135.0
# 2   354162.0                             0.0        290273.0
# 3   302832.0                             0.0        274094.0
# 4   170252.0                             0.0        179673.0
#
#     Unexpired Risk Reserve (B/F) .1  Net Earned Premium Income  \
# 0                               NaN                        NaN
# 1                               0.0                  3751434.0
# 2                               0.0                   947104.0
# 3                               0.0                   745572.0
# 4                               0.0                   500012.0
#
#    Incurred Claims  Net Commisions  Expense of Management   \
# 0              NaN             NaN                     NaN
# 1        2594960.0         56428.0               1123553.0
# 2         866212.0         29892.0                561554.0
# 3         314652.0       -455465.0                886279.0
# 4         329317.0         49269.0                282867.0
#
#    Underwriting Profit /(Loss)  Investment Income  Profit transferred to P&L
# 0                          NaN                NaN                        NaN
# 1                     -23507.0           341543.0                   318037.0
# 2                    -510554.0           101124.0                  -409430.0
# 3                        106.0                0.0                      106.0
# 4                    -161441.0           114589.0                   -46852.0

# %%
rev_20_17.to_csv("Gen_rev_20_17.csv")

# %% [markdown]
# ### 2016-2013

# %%
numbers = [100,92,65,69]
pages = []
for number in numbers:
    pages.append("Table "+str(number) )

# %%
files2= ["Annual-_Industry_Report_2016.xlsx","Annual Report 2015.xlsx","Annual-Report-2014-12.10.2015-Final.xlsx","Latest 2013 IRA Annual Report.xlsx"]
c=1
rev_16_13= pd.DataFrame()
for filz,page in zip(files2,pages):
    f2 = pd.ExcelFile(filz)
    try:
    ## reading the specific sheets
        sheet=  pd.read_excel(f2,page,header=1)
        sheet.columns=sheet.columns.str.upper()
        
        sheet.set_index("COMPANY",inplace=True)
        sheet_t=sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace(' ','_')
        sheet_t.columns = sheet_t.columns.str.replace('__','_')
        sheet_t.columns = sheet_t.columns.str.upper()
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.upper()
        rev_16_13 = pd.concat([rev_16_13,sheet_t])
    except KeyError:
        sheet=  pd.read_excel(f2,page,header=2)
        sheet.columns=sheet.columns.str.upper()
        sheet.columns=sheet.columns.str.upper()
        
        sheet.set_index("COMPANY",inplace=True)
        sheet_t=sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace(' ','_')
        sheet_t.columns = sheet_t.columns.str.replace('__','_')
        sheet_t.columns = sheet_t.columns.str.upper()
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.upper()
        rev_16_13 = pd.concat([rev_16_13,sheet_t])
        
    print(sheet_t.columns)
# Out:
# Index(['GROSS_DIRECT_PREMIUM', 'INWARD_REINSURANCE', 'OUTWARD_REINSURANCE',
#        'NET_PREMIUM_WRITTEN', 'UPR_B/F', 'UNEXPIRED_RISK_RESERVE_(B/F)',
#        'UPR_C/F', 'UNEXPIRED_RISK_RESERVE_(B/F).1',
#        'NET_EARNED_PREMIUM_INCOME', 'INCURRED_CLAIMS', 'NET_COMMISIONS',
#        'EXPENSE_OF_MANAGEMENT', 'UNDERWRITING_PROFIT_/(LOSS)',
#        'INVESTMENT_INCOME', 'PROFIT_TRANSFERRED_TO_P&L'],
#       dtype='object')
# Index(['GROSS_DIRECT_PREMIUM', 'INWARD_REINSURANCE', 'OUTWARD_REINSURANCE',
#        'NET_PREMIUM_WRITTEN', 'UPR_B/F', 'UNEXPIRED_RISK_RESERVE_(B/F)',
#        'UPR_C/F', 'UNEXPIRED_RISK_RESERVE_(B/F).1',
#        'NET_EARNED_PREMIUM_INCOME', 'INCURRED_CLAIMS', 'NET_COMMISIONS',
#        'EXPENSE_OF_MANAGEMENT', 'UNDERWRITING_PROFIT_/(LOSS)',
#        'INVESTMENT_INCOME', 'PROFIT_TRANSFERRED_TO_P&L'],
#       dtype='object')
# Index(['GROSS_DIRECT_PREMIUM', 'INWARD_REINSURANCE', 'OUTWARD_REINSURANCE',
#        'NET_PREMIUM_WRITTEN', 'UPR_B/F', 'UNEXPIRED_RISK_RESERVE_(B/F)',
#        'UPR_C/F', 'UNEXPIRED_RISK_RESERVE_(B/F).1',
#        'NET_EARNED_PREMIUM_INCOME', 'INCURRED_CLAIMS', 'NET_COMMISIONS',
#        'EXPENSE_OF_MANAGEMENT', 'UNDERWRITING_PROFIT_/(LOSS)',
#        'INVESTMENT_INCOME', 'PROFIT_TRANSFERRED_TO_P&L'],
#       dtype='object')
# Index(['GROSS_DIRECT_PREMIUM', 'INWARD_REINSURANCE', 'OUTWARD_REINSURANCE',
#        'NET_PREMIUM_WRITTEN', 'UPR_B/F', 'UNEXPIRED_RISK_RESERVE_(B/F)',
#        'UPR_C/F', 'UNEXPIRED_RISK_RESERVE_(B/F).1',
#        'NET_EARNED_PREMIUM_INCOME', 'INCURRED_CLAIMS', 'NET_COMMISIONS',
#        'EXPENSE_OF_MANAGEMENT', 'UNDERWRITING_PROFIT_/(LOSS)',
#        'INVESTMENT_INCOME', 'PROFIT_TRANSFERRED_TO_P&L'],
#       dtype='object')

# %%
rev_16_13.columns
# Out:
# Index(['GROSS_DIRECT_PREMIUM', 'INWARD_REINSURANCE', 'OUTWARD_REINSURANCE',
#        'NET_PREMIUM_WRITTEN', 'UPR_B/F', 'UNEXPIRED_RISK_RESERVE_(B/F)',
#        'UPR_C/F', 'UNEXPIRED_RISK_RESERVE_(B/F).1',
#        'NET_EARNED_PREMIUM_INCOME', 'INCURRED_CLAIMS', 'NET_COMMISIONS',
#        'EXPENSE_OF_MANAGEMENT', 'UNDERWRITING_PROFIT_/(LOSS)',
#        'INVESTMENT_INCOME', 'PROFIT_TRANSFERRED_TO_P&L'],
#       dtype='object')

# %%
rev_16_13.to_csv("Gen_rev_16_13.csv")

# %% [markdown]
# ## 2012-2010

# %%
numbers = [70,39]
pages = []
for number in numbers:
    pages.append("Table "+str(number) )

# %%
files2= ["IRA Annual Report 2012(1).xlsx","IRA ANNUAL REPORT 2011 FINAL.xlsx"]
c=1
rev_12_10= pd.DataFrame()
for filz,page in zip(files2,pages):
    f2 = pd.ExcelFile(filz)
    try:
    ## reading the specific sheets
        sheet=  pd.read_excel(f2,page,header=1)
        sheet.columns=sheet.columns.str.upper()
        #sheet.columns = sheet.columns.str.replace(' ','_')
        sheet.set_index("NAME OF INSURER",inplace=True)
        sheet_t=sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace('  ',' ')
        sheet_t.columns = sheet_t.columns.str.replace(' ','_')
        # sheet_t.columns = sheet_t.columns.str.replace('__','_')
        # sheet_t.columns = sheet_t.columns.str.upper()
        # sheet_t.columns = sheet_t.columns.str.strip()
        # sheet_t.columns = sheet_t.columns.str.upper()
        rev_12_10 = pd.concat([rev_12_10,sheet_t])
    except KeyError:
        sheet=  pd.read_excel(f2,page,header=2)
        sheet.columns=sheet.columns.str.upper()
        #sheet.columns=sheet.columns.str.upper()
        #sheet.columns = sheet.columns.str.replace(' ','_')
        sheet.set_index("NAME OF INSURER",inplace=True)
        sheet_t=sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace('  ',' ')
        sheet_t.columns = sheet_t.columns.str.replace(' ','_')
        # sheet_t.columns = sheet_t.columns.str.replace('__','_')
        # sheet_t.columns = sheet_t.columns.str.upper()
        # sheet_t.columns = sheet_t.columns.str.strip()
        # sheet_t.columns = sheet_t.columns.str.upper()
        rev_12_10 = pd.concat([rev_12_10,sheet_t])
        
    print(sheet_t.columns)
# Out:
# Index(['NO.', 'FUND_AT_THE_BEGINNING_OF_THE_YEAR', 'NET_PREMIUM',
#        'NET_INVESTMENT_INCOME', 'INVESTMENT_EXPENSE', 'CLAIMS_BY_DEATH',
#        'CLAIMS_BY_MATURITY', 'OTHER_CLAIMS', 'SURRENDERS',
#        'BONUSES_PAID_IN_CASH', 'ANNUITIES_PAID', 'COMMISSIONS',
#        'EXPENSE_OF_MANAGEMENT', 'OTHER_EXPENSES', 'TRANSFER_TO_P&L_ACCOUNT',
#        'FUND_AT_THE_END_OF_THE_YEAR'],
#       dtype='object')
# Index(['UNNAMED:_0', 'NO.', 'FUND_AT_THE_BEGINNING_OF_THE_YEAR', 'NET_PREMIUM',
#        'NET_INVESTMENT_INCOME', 'INVESTMENT_EXPENSE', 'CLAIMS_BY_DEATH',
#        'CLAIMS_BY_MATURITY', 'OTHER_CLAIMS', 'SURRENDERS',
#        'BONUSES_PAID_IN_CASH', 'ANNUITIES_PAID', 'COMMISSIONS',
#        'EXPENSE_OF_MANAGEMENT', 'OTHER_EXPENSES', 'TRANSFER_TO_P&L_ACCOUNT',
#        'FUND_AT_THE_END_OF_THE_YEAR'],
#       dtype='object')

# %%
rev_12_10.to_csv("Gen_rev_12_11.csv")

# %%
rev_12_10.columns
# Out:
# Index(['NO.', 'FUND_AT_THE_BEGINNING_OF_THE_YEAR', 'NET_PREMIUM',
#        'NET_INVESTMENT_INCOME', 'INVESTMENT_EXPENSE', 'CLAIMS_BY_DEATH',
#        'CLAIMS_BY_MATURITY', 'OTHER_CLAIMS', 'SURRENDERS',
#        'BONUSES_PAID_IN_CASH', 'ANNUITIES_PAID', 'COMMISSIONS',
#        'EXPENSE_OF_MANAGEMENT', 'OTHER_EXPENSES', 'TRANSFER_TO_P&L_ACCOUNT',
#        'FUND_AT_THE_END_OF_THE_YEAR', 'UNNAMED:_0'],
#       dtype='object')

# %% [markdown]
# ### summary of Life business combined revenue accounts

# %% [markdown]
# ## 2020-2017

# %%
files= ["2020-Annual-Insurance-Industry-Statistics(1).xls","2019 Annual Insurance Industry Statistics.xlsm","2018 Annual Statistics 28062019.xls","2017-Annual-Insurance-Statistics-Uploaded.xlsm"]
rev_20_17= pd.DataFrame()
c=0
for fil in files:
    c+=1
    f1 = pd.ExcelFile(fil)
    ## reading the specific sheets
    sheet1= pd.read_excel(f1,"APPENDIX 16",header=3)
    ### dropping the unnamed column
    #sheet1.drop("Unnamed: 1",axis=1,inplace=True)
    sheet1.drop("Unnamed: 0",axis=1,inplace=True)
    ### concatinating the data sheets
    rev_20_17 = pd.concat([rev_20_17,sheet1])

# %%
rev_20_17.to_csv("Life_rev_20_17.csv")

# %% [markdown]
# ## 2016-2013

# %%
numbers = [80,72,45,49]
pages = []
for number in numbers:
    pages.append("Table "+str(number) )

# %%
files2= ["Annual-_Industry_Report_2016.xlsx","Annual Report 2015.xlsx","Annual-Report-2014-12.10.2015-Final.xlsx","Latest 2013 IRA Annual Report.xlsx"]
c=1
rev_16_13= pd.DataFrame()
for filz,page in zip(files2,pages):
    f2 = pd.ExcelFile(filz)
    try:
    ## reading the specific sheets
        sheet=  pd.read_excel(f2,page,header=1)
        sheet.columns=sheet.columns.str.upper()
        
        sheet.set_index("COMPANY",inplace=True)
        sheet_t=sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace(' ','_')
        sheet_t.columns = sheet_t.columns.str.replace('__','_')
        sheet_t.columns = sheet_t.columns.str.upper()
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('MANAGMENT','MANAGEMENT')
        sheet_t.columns = sheet_t.columns.str.replace('INCURRED_CLAIMS','CLAIMS')
        sheet_t.columns = sheet_t.columns.str.replace('TOTAL_CLAIMS','CLAIMS')
        sheet_t.columns = sheet_t.columns.str.upper()
        rev_16_13 = pd.concat([rev_16_13,sheet_t])
    except KeyError:
        sheet=  pd.read_excel(f2,page,header=2)
        sheet.columns=sheet.columns.str.upper()
        sheet.columns=sheet.columns.str.upper()
        
        sheet.set_index("COMPANY",inplace=True)
        sheet_t=sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace(' ','_')
        sheet_t.columns = sheet_t.columns.str.replace('__','_')
        sheet_t.columns = sheet_t.columns.str.upper()
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('MANAGMENT','MANAGEMENT')
        sheet_t.columns = sheet_t.columns.str.replace('INCURRED_CLAIMS','CLAIMS')
        sheet_t.columns = sheet_t.columns.str.replace('TOTAL_CLAIMS','CLAIMS')
        sheet_t.columns = sheet_t.columns.str.upper()
        rev_16_13 = pd.concat([rev_16_13,sheet_t])
        
    print(sheet_t.columns)
# Out:
# Index(['LIFE_FUND_BF', 'GROSS_PREMIUM', 'NET_PREMIUM', 'OTHER_(FEE)_INCOME',
#        'TOTAL_BENEFITS', 'CLAIMS', 'SURRENDERS', 'BONUSES_PAID',
#        'ANNUITIES_PAID', 'NET_COMMISIONS', 'EXPENSE_OF_MANAGEMENT',
#        'INVESTMENT_INCOME', 'INVESTMENT_EXPENSES', 'TRANSFER_TO_(FROM)_P_&_L',
#        'LIFE_FUND_CF'],
#       dtype='object')
# Index(['LIFE_FUND_BF', 'GROSS_PREMIUM', 'NET_PREMIUM', 'OTHER_(FEE)_INCOME',
#        'CLAIMS', 'SURRENDERS', 'BONUSES_PAID', 'ANNUITIES_PAID',
#        'NET_COMMISIONS', 'EXPENSE_OF_MANAGEMENT', 'INVESTMENT_INCOME',
#        'INVESTMENT_EXPENSES', 'TRANSFER_TO_(FROM)_P_&_L', 'LIFE_FUND_CF'],
#       dtype='object')
# Index(['LIFE_FUND_BF', 'GROSS_PREMIUM', 'NET_PREMIUM', 'OTHER_(FEE)_INCOME',
#        'CLAIMS', 'SURRENDERS', 'BONUSES_PAID', 'ANNUITIES_PAID',
#        'NET_COMMISIONS', 'EXPENSE_OF_MANAGEMENT', 'INVESTMENT_INCOME',
#        'INVESTMENT_EXPENSES', 'TRANSFER_TO_(FROM)_P_&_L', 'LIFE_FUND_CF'],
#       dtype='object')
# Index(['LIFE_FUND_BF', 'GROSS_PREMIUM', 'NET_PREMIUM', 'OTHER_(FEE)_INCOME',
#        'TOTAL_BENEFITS', 'CLAIMS', 'SURRENDERS', 'BONUSES_PAID',
#        'ANNUITIES_PAID', 'NET_COMMISIONS', 'EXPENSE_OF_MANAGEMENT',
#        'INVESTMENT_INCOME', 'INVESTMENT_EXPENSES', 'TRANSFER_TO_(FROM)_P_&_L',
#        'LIFE_FUND_CF'],
#       dtype='object')

# %%
rev_16_13.to_csv("Life_rev_16_13.csv")

# %%
len(rev_16_13.columns)
# Out:
# 15

# %% [markdown]
# ### 2012-2010

# %%
numbers = [71,40,44]
pages = []
for number in numbers:
    pages.append("Table "+str(number) )

# %%
files2= ["IRA Annual Report 2012(1).xlsx","IRA ANNUAL REPORT 2011 FINAL.xlsx","2010 insurance industry report.xlsx"]
c=1
rev_12_10= pd.DataFrame()
for filz,page in zip(files2,pages):
    f2 = pd.ExcelFile(filz)
    try:
    ## reading the specific sheets
        sheet=  pd.read_excel(f2,page,header=1)
        sheet.columns=sheet.columns.str.upper()
        #sheet.columns = sheet.columns.str.replace(' ','_')
        sheet.set_index("NAME OF INSURER",inplace=True)
        sheet_t=sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace(' ','_')
        # sheet_t.columns = sheet_t.columns.str.replace('__','_')
        # sheet_t.columns = sheet_t.columns.str.upper()
        # sheet_t.columns = sheet_t.columns.str.strip()
        # sheet_t.columns = sheet_t.columns.str.upper()
        rev_12_10 = pd.concat([rev_12_10,sheet_t])
    except KeyError:
        sheet=  pd.read_excel(f2,page,header=2)
        sheet.columns=sheet.columns.str.upper()
        #sheet.columns=sheet.columns.str.upper()
        #sheet.columns = sheet.columns.str.replace(' ','_')
        sheet.set_index("NAME OF INSURER",inplace=True)
        sheet_t=sheet
        sheet_t.columns = sheet_t.columns.str.strip()
        sheet_t.columns = sheet_t.columns.str.replace('\n',' ')
        sheet_t.columns = sheet_t.columns.str.replace(' ','_')
        # sheet_t.columns = sheet_t.columns.str.replace('__','_')
        # sheet_t.columns = sheet_t.columns.str.upper()
        # sheet_t.columns = sheet_t.columns.str.strip()
        # sheet_t.columns = sheet_t.columns.str.upper()
        rev_12_10 = pd.concat([rev_12_10,sheet_t])
        
    print(sheet_t.columns)
# Out:
# Index(['NO.', 'FUND_AT_THE_BEGINNING_OF_THE_YEAR', 'NET_PREMIUM',
#        'GROSS_INVESTMENT_INCOME', 'INVESTMENT_EXPENSE',
#        'NET_INVESTMENT_INCOME', 'CLAIMS_BY_DEATH', 'CLAIMS_BY_MATURITY',
#        'OTHER_CLAIMS', 'SURRENDERS', 'BONUSES_PAID_IN_CASH', 'ANNUITIES_PAID',
#        'COMMISSIONS', 'EXPENSE_OF_MANAGEMENT', 'OTHER_EXPENSES',
#        'TRANSFER_TO_P&L_ACCOUNT', 'FUND_AT_THE_END_OF_THE_YEAR'],
#       dtype='object')
# Index(['NO.', 'FUND_AT_THE_BEGINNING_OF_THE_YEAR', 'NET_PREMIUM',
#        'NET_INVESTMENT_INCOME', 'INVESTMENT_EXPENSE', 'CLAIMS_BY_DEATH',
#        'CLAIMS_BY_MATURITY', 'OTHER_CLAIMS', 'SURRENDERS',
#        'BONUSES_PAID_IN_CASH', 'ANNUITIES_PAID', 'COMMISSIONS',
#        'EXPENSE_OF_MANAGEMENT', 'OTHER_EXPENSES', 'TRANSFER_TO_P&L_ACCOUNT',
#        'FUND_AT_THE_END_OF_THE_YEAR'],
#       dtype='object')
# Index(['NO.', 'UNNAMED:_1', 'FUND_AT_THE_BEGINNING_OF_THE_YEAR', 'NET_PREMIUM',
#        'NET_INVESTMENT_INCOME', 'INVESTMENT_EXPENSE', 'CLAIMS_BY_DEATH',
#        'CLAIMS_BY_MATURITY', 'OTHER_CLAIMS', 'SURRENDERS',
#        'BONUSES_PAID_IN_CASH', 'ANNUITIES_PAID', 'COMMISSIONS',
#        'EXPENSE_OF_MANAGEMENT', 'OTHER_EXPENSES', 'TRANSFER_TO_P&L_ACCOUNT',
#        'FUND_AT_THE_END_OF_THE_YEAR'],
#       dtype='object')

# %%
rev_12_10.to_csv("Life_rev_12_10.csv")

# %%
rev_12_10.columns
# Out:
# Index(['NO.', 'FUND_AT_THE_BEGINNING_OF_THE_YEAR', 'NET_PREMIUM',
#        'GROSS_INVESTMENT_INCOME', 'INVESTMENT_EXPENSE',
#        'NET_INVESTMENT_INCOME', 'CLAIMS_BY_DEATH', 'CLAIMS_BY_MATURITY',
#        'OTHER_CLAIMS', 'SURRENDERS', 'BONUSES_PAID_IN_CASH', 'ANNUITIES_PAID',
#        'COMMISSIONS', 'EXPENSE_OF_MANAGEMENT', 'OTHER_EXPENSES',
#        'TRANSFER_TO_P&L_ACCOUNT', 'FUND_AT_THE_END_OF_THE_YEAR', 'UNNAMED:_1'],
#       dtype='object')
